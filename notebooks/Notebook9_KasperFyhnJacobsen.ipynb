# %% [markdown]
# # Notebook 9: Getting lines from just one speaker
# ### Kasper Fyhn Jacobsen
#
# Once again, I was in the pleasant situation where my childes_transcripts module and namely the `Transcript` class was already able to do this. However, since I had not used it that much yet myself, this made an ideal situation to improve it. As always, the module can be seen [here](https://github.com/KasperFyhn/ChildLangAcqui/blob/master/src/childes_transcripts.py) on GitHub.
#
# ## Improving the class
#
# Before, I had defined an instance method to return all non-header lines as tuples with `tuple[0]` being the speaker or comment/annotation-type and `tuple[1]` being the actual line. In the class constructur, i.e. the `__init__()` method, an instance variable `lines` (now changed to `raw_lines`) is created; this variable is a list of all raw lines except headers. The method simply tweaked each line into a tuple as described and returned it, like this:
#
# ```python
# def lines_as_tuples(self):
#     '''Return a list of tuples of all utterance lines, where tuple[0] is
#     the three letter initials for the speaker and tuple[1] is the line.'''
#
#     tuples = [(line[1:4], line[5:]) for line in self.lines]
#
#     return tuples
# ```
#
# The `tokens()` method relied on this method. So, I did two things: 1) I made it possible to call for lines for just one or more specified speakers and 2) I removed the "speaker missing" warning from the `tokens()` method and put it to be done in this `lines_as_tuples()` method. Then, it looked like this.
#
# ```python
# def lines_as_tuples(self, speakers='all'):
#     '''Return a list of tuples of all utterance lines, where tuple[0] is
#     the three letter initials for the speaker and tuple[1] is the line. One
#     or more speakers can be specified to retrieve just lines by these.'''
#
#     tuples = [(line[1:4], line[5:]) for line in self.lines]
#
#     # sort the list to contain only the specified speakers
#     if not speakers == 'all':
#         if type(speakers) == str:
#             speakers = [speakers]
#         tuples = [line for line in tuples if line[0] in speakers]
#
#         # check if the requested speakers are present in the transcript
#         # and report if they are not
#         for speaker in speakers:
#             if speaker not in self.speakers():
#                 print(f'WARNING: The speaker {speaker} is not present ' +
#                       f'in the transcript {self.name}.')
#
#     return tuples
# ```
#
# And I thought I was finished. But, then, I remembered the annotations which I figured might be needed in some situations. Just getting these out was easy enough: just put the name of the annotation tier in the list of requested speakers. However, this would give ALL of the annotations and not just the ones for the lines that we requested. It would also give a few warning messages. So I moved on to making this possible and ended up making it like this, a now more versatile method:
#
# ```python
# def lines_as_tuples(self, speakers='all', morphosyntax=False,
#                     grammar=False, actions=False):
#     '''Return a list of tuples of all utterance lines, where tuple[0] is
#     the three letter initials for the speaker and tuple[1] is the line. One
#     or more speakers can be specified to retrieve just lines by these and
#     one or more flags can be marked to get annotations for the requested
#     speaker(s).'''
#
#     if speakers == 'all':
#         speakers = self.speakers()
#     if type(speakers) == str: # make sure that it is a list
#         speakers = [speakers]
#
#     # check if the requested speakers are present in the transcript
#     # and report if they are not
#     for speaker in speakers:
#         if speaker not in self.speakers():
#             print(f'WARNING: The speaker {speaker} is not present ' +
#                   f'in the transcript {self.name}.')
#
#     if morphosyntax == True:
#         speakers.append('mor')
#     if grammar == True:
#         speakers.append('gra')
#     if actions == True:
#         speakers.append('act')
#
#     # make list with lines as three part tuples
#     tuples = [(line[0], line[1:4], line[5:]) for line in self.lines]
#
#     # divide into blocks of turns with their annotations
#     blocks = []
#     for line in tuples:
#         if line[0] == '*':
#             blocks.append([])
#             blocks[-1] = [(line[1], line[2])]
#         elif line[0] == '%':
#             blocks[-1].append((line[1], line[2]))
#
#     # put together the blocks of the requested speakers along with the
#     # requested annotations
#     tuples = []
#     for block in blocks:
#         if block[0][0] in speakers:
#             tuples += [line for line in block if line[0] in speakers]
#
#     return tuples
# ```
#
# ## Seeing it in action - a few examples

# %%
import os
os.chdir(r'C:\Users\Kasper Fyhn Jacobsen\python-projects\ChildLangAcqui\src')
import childes_transcripts as ts

transcript = ts.Transcript(r'C:\Users\Kasper Fyhn Jacobsen\python-projects\ChildLangAcqui\data\Kuczaj\020606.cha')

# spoken lines by all speakers
transcript.lines_as_tuples()
# Out:
# [('CHI', 'Momma (.) draw Momma (.) draw please draw .'),
#  ('MOT', 'Abe (.) I have_to eat breakfast before I can draw .'),
#  ('MOT', 'here (.) you draw .'),
#  ('CHI', 'this is broken (.) Mom .'),
#  ('MOT', "what's broke ?"),
#  ('CHI', 'this is broke .'),
#  ('MOT', 'draw with another one „ okay ?'),
#  ('CHI', "that's not paper ."),
#  ('MOT', "that isn't paper ."),
#  ('CHI', "uhuh that's not paper in here ."),
#  ('CHI', "Momma (.) I don't want this picture ."),
#  ('MOT', 'how come ?'),
#  ('CHI', 'huh .'),
#  ('MOT', "how come you don't want that picture ?"),
#  ('MOT', 'you drew it .'),
#  ('CHI', "it's broken ."),
#  ('MOT', "oh ‡ the paper's ripped ."),
#  ('MOT', 'here (.) draw on this .'),
#  ('CHI', 'this is a picture .'),
#  ('CHI', 'this is not paper .'),
#  ('MOT', "that's orange paper ."),
#  ('CHI', "oh ‡ we didn't get orange paper (.) Mom ."),
#  ('MOT', 'go ahead .'),
#  ('MOT', 'you can draw on it .'),
#  ('CHI', 'here (.) Mom see eyes .'),
#  ('CHI', 'see the eyes .'),
#  ('MOT', 'oh ‡ Abe made two red eyes (.) Dad .'),
#  ('FAT', 'wow !'),
#  ('CHI', 'a bigger eye this is a +...'),
#  ('MOT', 'Stan (.) put this in your desk drawer .'),
#  ('MOT', "so we'll have it when we need it next time „ okay ?"),
#  ('FAT', 'okay ‡ give it here .'),
#  ('CHI', "we haven't need it in a long time ."),
#  ('FAT', 'we might need it again though .'),
#  ('CHI', 'this is white .'),
#  ('MOT', 'uhhuh .'),
#  ('CHI', 'this white x@l .'),
#  ('MOT', 'you made a white x@l .'),
#  ('CHI', "Mama (.) what's on here ?"),
#  ('MOT', 'this is a brochure which tells us that our street will be repaired'),
#  ('CHI', 'Mama (.) I want white paper .'),
#  ('CHI', 'I want white paper now .'),
#  ('CHI', "that's paper , white paper ."),
#  ('MOT', 'here you go .'),
#  ('CHI', 'this is for you (.) Mom .'),
#  ('MOT', 'okay ‡ I always wanted a painting .'),
#  ('CHI', 'this is be a ladder .'),
#  ('MOT', "wow (.) Abe's making a ladder ."),
#  ('FAT', 'is somebody going to climb it ?'),
#  ('CHI', 'uhhuh (.) Mommy (.) here .'),
#  ('FAT', "that's a neat ladder (.) Abe ."),
#  ('CHI', 'this is not for you .'),
#  ('FAT', "it's not for me ."),
#  ('CHI', 'uhuh .'),
#  ('FAT', "who's it for ?"),
#  ('CHI', 'Mommy .'),
#  ('FAT', "oh ‡ it's beautiful (.) Abe ."),
#  ('CHI', 'my mommy like it .'),
#  ('FAT', 'I like it .'),
#  ('CHI', 'my mommy liked it .'),
#  ('FAT', 'I like it .'),
#  ('CHI', 'my mommy liked it .'),
#  ('FAT', 'I do too .'),
#  ('CHI', 'you like red ?'),
#  ('FAT', 'uhhuh (.) I like red .'),
#  ('CHI', 'here red !'),
#  ('FAT', 'uhhuh .'),
#  ('CHI', 'we got this and this too .'),
#  ('CHI', "it's ours ."),
#  ('CHI', 'you like this too ?'),
#  ('FAT', 'uhhuh what color is it ?'),
#  ('CHI', "<it's not> [//] it's orange ."),
#  ('CHI', "orange it's orange ."),
#  ('CHI', 'this is orange dot: dot !'),
#  ('CHI', 'dot !'),
#  ('CHI', 'dot !'),
#  ('FAT', 'are you making dots ?'),
#  ('CHI', 'uhhuh Momma (.) come see this ladder (.) I made .'),
#  ('MOT', "that's really a neat ladder ."),
#  ('CHI', "it's for firemans [: firemen] [* s] ."),
#  ('MOT', "it's for fireman to climb up ?"),
#  ('CHI', 'uhhuh fireman put out fire !'),
#  ('MOT', 'uhhuh and painters use ladders to paint buildings .'),
#  ('CHI', 'not this house !'),
#  ('MOT', 'not yet but they will soon .'),
#  ('CHI', 'this is ours .'),
#  ('CHI', 'this is ours .'),
#  ('CHI', 'what happen (.) Mom ?'),
#  ('MOT', 'to what ?'),
#  ('CHI', 'to this house .'),
#  ('MOT', 'the sun went behind a cloud .'),
#  ('MOT', "so it's not as bright in here ."),
#  ('CHI', 'I wanna turn it on .'),
#  ('MOT', 'turn what on ?'),
#  ('CHI', 'my light on .'),
#  ('CHI', "you're not Abe !"),
#  ('MOT', "that's right ."),
#  ('CHI', "you're not Stan ."),
#  ('CHI', 'you are Ann !'),
#  ('MOT', "that's right ."),
#  ('MOT', "I'm Ann ."),
#  ('CHI', 'and two eyes (.) Mom .'),
#  ('MOT', "uhhuh I'm going to go out and water the garden ."),
#  ('CHI', "I don't want to ."),
#  ('MOT', 'okay ‡ you can stay in here with Daddy .'),
#  ('CHI', 'where my ladder ?'),
#  ('CHI', 'here it is .'),
#  ('CHI', 'wanna poopoo Daddy .'),
#  ('CHI', 'I wanna poopoo .'),
#  ('FAT', "okay ‡ I'll help you ."),
#  ('FAT', 'come on .'),
#  ('CHI', 'I wanna come back hurry !'),
#  ('FAT', "okay ‡ let's hurry drawing pictures again ."),
#  ('CHI', 'Daddy this is for you .'),
#  ('CHI', 'you take for school !'),
#  ('FAT', 'oh ‡ what a neat picture .'),
#  ('FAT', 'I sure am going to take it to school .'),
#  ('CHI', 'I wanna go for school with you .'),
#  ('FAT', 'okay ‡ you can come tomorrow .'),
#  ('FAT', 'okay ‡ Mommy will bring you .'),
#  ('CHI', 'okay ‡ I wanna watch tv .'),
#  ('CHI', 'I wanna watch tv .'),
#  ('FAT', "there's nothing on tv ."),
#  ('CHI', "why don't we play a game „ okay ?"),
#  ('FAT', "let's play hide and seek ."),
#  ('FAT', "see (.) I'll hide under the table ."),
#  ('CHI', 'Daddy (.) birdie !'),
#  ('FAT', 'a birdie !'),
#  ('FAT', 'where at ?'),
#  ('CHI', 'outside .'),
#  ('FAT', "oh ‡ the birdie's outside !"),
#  ('CHI', 'uhhuh (.) my mommy got a doggy .'),
#  ('FAT', 'she did ?'),
#  ('CHI', 'uhhuh in here .'),
#  ('CHI', 'and we go to park .'),
#  ('FAT', 'you went to a park ?'),
#  ('CHI', 'we go park afternoon .'),
#  ('FAT', "oh ‡ you're going to a park this afternoon ."),
#  ('CHI', 'uhhuh Como_Park .'),
#  ('FAT', "oh ‡ you're going to Como_Park ?"),
#  ('CHI', 'to Como_Park: .'),
#  ('CHI', 'I wanna go to Como_Park .'),
#  ('CHI', 'see the ducks ?'),
#  ('FAT', 'you wanna see the ducks ?'),
#  ('CHI', 'uhhuh I like that .'),
#  ('FAT', 'you sure are likable !'),
#  ('CHI', "I'm not likable !"),
#  ('FAT', "you're not ?"),
#  ('CHI', 'you are likable .'),
#  ('FAT', 'I am ?'),
#  ('CHI', 'uhhuh .'),
#  ('FAT', 'thank_you .'),
#  ('CHI', 'a cow in the barn .'),
#  ('FAT', "a cow's in the barn ?"),
#  ('CHI', 'uhhuh that barn .'),
#  ('FAT', "oh ‡ a cow's in your barn !"),
#  ('CHI', "uhhuh (.) oh (.) I'm sorry ."),
#  ('FAT', "that's okay ."),
#  ('CHI', 'girl (.) girl (.) girl !'),
#  ('FAT', 'go ahead and get the girl .'),
#  ('FAT', "a man's in the car ."),
#  ('CHI', "who's in the car ?"),
#  ('CHI', "a man's in the car ."),
#  ('FAT', "that's right ."),
#  ('FAT', "a man's in the car ."),
#  ('CHI', 'a funny man in the car and a silly man in the car .'),
#  ('FAT', 'what a bunch of silly people in the car .'),
#  ('FAT', 'oh ‡ look out you almost got me .'),
#  ('CHI', "I didn't got you ."),
#  ('FAT', 'you almost got me .'),
#  ('CHI', "no ‡ I didn't ."),
#  ('FAT', "you're silly ."),
#  ('CHI', 'I got you .'),
#  ('CHI', 'I got you .'),
#  ('CHI', 'help me !'),
#  ('FAT', "I'll help you ."),
#  ('FAT', "I'm going to tickle you ."),
#  ('CHI', 'no !'),
#  ('FAT', 'yes I am .'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('CHI', 'no !'),
#  ('FAT', "okay ‡ I won't ."),
#  ('CHI', 'I got it .'),
#  ('CHI', 'I got it .'),
#  ('CHI', "you can't get it ."),
#  ('CHI', "you can't get it ."),
#  ('FAT', "I can't get it ?"),
#  ('CHI', "you can't ."),
#  ('CHI', 'I can .'),
#  ('CHI', 'upside down merrygoround merrygoround .'),
#  ('FAT', "you're going to get dizzy ."),
#  ('CHI', 'Poe_Ray_Me read that at the store „ right ?'),
#  ('FAT', 'we can sing it here if you want to .'),
#  ('FAT', 'do you want to ?'),
#  ('CHI', 'uhhuh .'),
#  ('FAT', 'oh ‡ let me see your sore on your foot .'),
#  ('CHI', "I didn't got a sore ."),
#  ('FAT', "you don't ?"),
#  ('CHI', 'uhuh .'),
#  ('FAT', "you're right ."),
#  ('FAT', "it's just some paint ."),
#  ('CHI', 'see this ?'),
#  ('CHI', 'I hurt self outside .'),
#  ('FAT', 'you hurt yourself outside ?'),
#  ('FAT', 'let me see your hand .'),
#  ('CHI', 'on a chair , a green chair .'),
#  ('FAT', 'how ?'),
#  ('CHI', 'stuck .'),
#  ('FAT', 'you know what ?'),
#  ('FAT', 'you need to have your fingernails cut .'),
#  ('CHI', 'what fingernails ?'),
#  ('FAT', 'see (.) right here ?'),
#  ('FAT', 'see how long they are ?'),
#  ('CHI', "uhhuh I don't want a fingernail cut ."),
#  ('CHI', "I don't want a fingernail cut ."),
#  ('FAT', 'sure you do .'),
#  ('CHI', "I don't want to you do on your toes !"),
#  ('FAT', "you're crazy ."),
#  ('FAT', 'your fingernails are long .'),
#  ('FAT', 'my toenails are short .'),
#  ('FAT', 'so are yours .'),
#  ('FAT', 'your toenails are in pretty good shape .'),
#  ('CHI', 'no ‡ my toes are not pretty good shape .'),
#  ('FAT', 'they are too .'),
#  ('CHI', 'they are round and circles .'),
#  ('CHI', 'you funny dummy .'),
#  ('FAT', "you're a silly goose ."),
#  ('CHI', 'you are a silly goose too .'),
#  ('CHI', 'a goose flewed [: flew] [* m:ed] .'),
#  ('CHI', 'no ‡ flew away .'),
#  ('CHI', 'you flew away .'),
#  ('FAT', 'you fly away !'),
#  ('CHI', 'no ‡ you .')]

# %%
# morphosyntactically annotated lines by the father
transcript.lines_as_tuples(speakers='FAT', morphosyntax=True)
# Out:
# [('FAT', 'wow !'),
#  ('mor', 'co|wow !'),
#  ('FAT', 'okay ‡ give it here .'),
#  ('mor', 'co|okay beg|beg v|give pro:per|it adv|here .'),
#  ('FAT', 'we might need it again though .'),
#  ('mor', 'pro:sub|we mod|might v|need pro:per|it adv|again adv|though .'),
#  ('FAT', 'is somebody going to climb it ?'),
#  ('mor', 'aux|be&3S pro:indef|somebody part|go-PRESP inf|to v|climb'),
#  ('FAT', "that's a neat ladder (.) Abe ."),
#  ('mor', 'pro:dem|that~cop|be&3S det:art|a adj|neat n|ladder n:prop|Abe .'),
#  ('FAT', "it's not for me ."),
#  ('mor', 'pro:per|it~cop|be&3S neg|not prep|for pro:obj|me .'),
#  ('FAT', "who's it for ?"),
#  ('mor', 'pro:rel|who~aux|be&3S pro:per|it prep|for ?'),
#  ('FAT', "oh ‡ it's beautiful (.) Abe ."),
#  ('mor', 'co|oh beg|beg pro:per|it~cop|be&3S adj|beautiful n:prop|Abe .'),
#  ('FAT', 'I like it .'),
#  ('mor', 'pro:sub|I v|like pro:per|it .'),
#  ('FAT', 'I like it .'),
#  ('mor', 'pro:sub|I v|like pro:per|it .'),
#  ('FAT', 'I do too .'),
#  ('mor', 'pro:sub|I v|do post|too .'),
#  ('FAT', 'uhhuh (.) I like red .'),
#  ('mor', 'co|uhhuh pro:sub|I co|like n|red .'),
#  ('FAT', 'uhhuh .'),
#  ('mor', 'co|uhhuh .'),
#  ('FAT', 'uhhuh what color is it ?'),
#  ('mor', 'co|uhhuh pro:int|what n|color aux|be&3S pro:per|it ?'),
#  ('FAT', 'are you making dots ?'),
#  ('mor', 'cop|be&PRES pro:per|you part|make-PRESP n|dot-PL ?'),
#  ('FAT', "okay ‡ I'll help you ."),
#  ('mor', 'co|okay beg|beg pro:sub|I~mod|will v|help pro:per|you .'),
#  ('FAT', 'come on .'),
#  ('mor', 'v|come adv|on .'),
#  ('FAT', "okay ‡ let's hurry drawing pictures again ."),
#  ('mor', 'co|okay beg|beg v|let~pro:obj|us v|hurry n|drawing n|picture-PL'),
#  ('FAT', 'oh ‡ what a neat picture .'),
#  ('mor', 'co|oh beg|beg pro:int|what det:art|a adj|neat n|picture .'),
#  ('FAT', 'I sure am going to take it to school .'),
#  ('mor', 'pro:sub|I v|sure aux|be&1S part|go-PRESP inf|to v|take pro:per|it'),
#  ('FAT', 'okay ‡ you can come tomorrow .'),
#  ('mor', 'co|okay beg|beg pro:per|you mod|can v|come adv:tem|tomorrow .'),
#  ('FAT', 'okay ‡ Mommy will bring you .'),
#  ('mor', 'co|okay beg|beg n:prop|Mommy mod|will v|bring pro:per|you .'),
#  ('FAT', "there's nothing on tv ."),
#  ('mor', 'pro:exist|there~cop|be&3S pro:indef|nothing prep|on n|tv .'),
#  ('FAT', "let's play hide and seek ."),
#  ('mor', 'v|let~pro:obj|us v|play n|hide coord|and v|seek .'),
#  ('FAT', "see (.) I'll hide under the table ."),
#  ('mor', 'co|see pro:sub|I~mod|will v|hide prep|under det:art|the n|table .'),
#  ('FAT', 'a birdie !'),
#  ('mor', 'det:art|a n|bird-DIM !'),
#  ('FAT', 'where at ?'),
#  ('mor', 'adv:int|where prep|at ?'),
#  ('FAT', "oh ‡ the birdie's outside !"),
#  ('mor', 'co|oh beg|beg det:art|the n|bird-DIM~aux|be&3S adv|outside !'),
#  ('FAT', 'she did ?'),
#  ('mor', 'pro:sub|she v|do&PAST ?'),
#  ('FAT', 'you went to a park ?'),
#  ('mor', 'pro:per|you v|go&PAST prep|to det:art|a n|park ?'),
#  ('FAT', "oh ‡ you're going to a park this afternoon ."),
#  ('mor', 'co|oh beg|beg pro:per|you~aux|be&PRES part|go-PRESP prep|to'),
#  ('FAT', "oh ‡ you're going to Como_Park ?"),
#  ('mor', 'co|oh beg|beg pro:per|you~aux|be&PRES part|go-PRESP prep|to'),
#  ('FAT', 'you wanna see the ducks ?'),
#  ('mor', 'pro:per|you mod:aux|wanna v|see det:art|the n|duck-PL ?'),
#  ('FAT', 'you sure are likable !'),
#  ('mor', 'pro:per|you adj|sure aux|be&PRES adj|like&dv-ABLE !'),
#  ('FAT', "you're not ?"),
#  ('mor', 'pro:per|you~aux|be&PRES neg|not ?'),
#  ('FAT', 'I am ?'),
#  ('mor', 'pro:sub|I aux|be&1S ?'),
#  ('FAT', 'thank_you .'),
#  ('mor', 'co|thank_you .'),
#  ('FAT', "a cow's in the barn ?"),
#  ('mor', 'det:art|a n|cow~poss|s prep|in det:art|the n|barn ?'),
#  ('FAT', "oh ‡ a cow's in your barn !"),
#  ('mor',
#   'co|oh beg|beg det:art|a n|cow~poss|s prep|in det:poss|your n|barn !'),
#  ('FAT', "that's okay ."),
#  ('mor', 'pro:dem|that~cop|be&3S adj|okay .'),
#  ('FAT', 'go ahead and get the girl .'),
#  ('mor', 'v|go adv|ahead coord|and v|get det:art|the n|girl .'),
#  ('FAT', "a man's in the car ."),
#  ('mor', 'det:art|a n|man~poss|s prep|in det:art|the n|car .'),
#  ('FAT', "that's right ."),
#  ('mor', 'pro:dem|that~cop|be&3S n|right .'),
#  ('FAT', "a man's in the car ."),
#  ('mor', 'det:art|a n|man~poss|s prep|in det:art|the n|car .'),
#  ('FAT', 'what a bunch of silly people in the car .'),
#  ('mor', 'pro:int|what det:art|a n|bunch prep|of adj|silly n|person&PL'),
#  ('FAT', 'oh ‡ look out you almost got me .'),
#  ('mor', 'co|oh beg|beg v|look adv|out pro:per|you adv|almost v|get&PAST'),
#  ('FAT', 'you almost got me .'),
#  ('mor', 'pro:per|you adv|almost v|get&PAST pro:obj|me .'),
#  ('FAT', "you're silly ."),
#  ('mor', 'pro:per|you~cop|be&PRES adj|silly .'),
#  ('FAT', "I'll help you ."),
#  ('mor', 'pro:sub|I~mod|will v|help pro:per|you .'),
#  ('FAT', "I'm going to tickle you ."),
#  ('mor', 'pro:sub|I~aux|be&1S part|go-PRESP inf|to v|tickle pro:per|you .'),
#  ('FAT', 'yes I am .'),
#  ('mor', 'co|yes pro:sub|I aux|be&1S .'),
#  ('FAT', "okay ‡ I won't ."),
#  ('mor', 'co|okay beg|beg pro:sub|I mod|will~neg|not .'),
#  ('FAT', "I can't get it ?"),
#  ('mor', 'pro:sub|I mod|can~neg|not v|get pro:per|it ?'),
#  ('FAT', "you're going to get dizzy ."),
#  ('mor', 'pro:per|you~aux|be&PRES part|go-PRESP inf|to v|get adj|dizzy .'),
#  ('FAT', 'we can sing it here if you want to .'),
#  ('mor', 'pro:sub|we mod|can v|sing pro:per|it adv|here conj|if pro:per|you'),
#  ('FAT', 'do you want to ?'),
#  ('mor', 'mod|do pro:per|you v|want prep|to ?'),
#  ('FAT', 'oh ‡ let me see your sore on your foot .'),
#  ('mor', 'co|oh beg|beg v|let&ZERO pro:obj|me v|see det:poss|your adj|sore'),
#  ('FAT', "you don't ?"),
#  ('mor', 'pro:per|you mod|do~neg|not ?'),
#  ('FAT', "you're right ."),
#  ('mor', 'pro:per|you~aux|be&PRES n|right .'),
#  ('FAT', "it's just some paint ."),
#  ('mor', 'pro:per|it~cop|be&3S adj|just qn|some n|paint .'),
#  ('FAT', 'you hurt yourself outside ?'),
#  ('mor', 'pro:per|you v|hurt&ZERO pro:refl|yourself adv|outside ?'),
#  ('FAT', 'let me see your hand .'),
#  ('mor', 'v|let&ZERO pro:obj|me v|see det:poss|your n|hand .'),
#  ('FAT', 'how ?'),
#  ('mor', 'adv:int|how ?'),
#  ('FAT', 'you know what ?'),
#  ('mor', 'pro:per|you v|know pro:int|what ?'),
#  ('FAT', 'you need to have your fingernails cut .'),
#  ('mor', 'pro:per|you v|need inf|to v|have det:poss|your'),
#  ('FAT', 'see (.) right here ?'),
#  ('mor', 'v|see adv|right adv|here ?'),
#  ('FAT', 'see how long they are ?'),
#  ('mor', 'v|see adv:int|how adv|long pro:sub|they cop|be&PRES ?'),
#  ('FAT', 'sure you do .'),
#  ('mor', 'adj|sure pro:per|you v|do .'),
#  ('FAT', "you're crazy ."),
#  ('mor', 'pro:per|you~aux|be&PRES adj|craze&dv-Y .'),
#  ('FAT', 'your fingernails are long .'),
#  ('mor', 'det:poss|your n|+n|finger+n|nail-PL cop|be&PRES adv|long .'),
#  ('FAT', 'my toenails are short .'),
#  ('mor', 'det:poss|my n|+n|toe+n|nail-PL cop|be&PRES adj|short .'),
#  ('FAT', 'so are yours .'),
#  ('mor', 'adv|so cop|be&PRES pro:poss|yours .'),
#  ('FAT', 'your toenails are in pretty good shape .'),
#  ('mor', 'det:poss|your n|+n|toe+n|nail-PL aux|be&PRES adv|in adv|pretty'),
#  ('FAT', 'they are too .'),
#  ('mor', 'pro:sub|they aux|be&PRES adv|too .'),
#  ('FAT', "you're a silly goose ."),
#  ('mor', 'pro:per|you~aux|be&PRES det:art|a adj|silly n|goose .'),
#  ('FAT', 'you fly away !'),
#  ('mor', 'pro:per|you v|fly adv|away !')]

# %%
# grammar and actions annotated lines by the mother and the child (excluding the father)
transcript.lines_as_tuples(speakers=['MOT', 'CHI'], morphosyntax=True, actions=True)
# Out:
# [('CHI', 'Momma (.) draw Momma (.) draw please draw .'),
#  ('mor', 'n:prop|Momma v|draw n:prop|Momma v|draw co|please v|draw .'),
#  ('MOT', 'Abe (.) I have_to eat breakfast before I can draw .'),
#  ('mor', 'n:prop|Abe pro:sub|I mod:aux|have_to v|eat n|breakfast conj|before'),
#  ('MOT', 'here (.) you draw .'),
#  ('mor', 'adv|here pro:per|you v|draw .'),
#  ('CHI', 'this is broken (.) Mom .'),
#  ('mor', 'pro:dem|this aux|be&3S part|break&PASTP n:prop|Mom .'),
#  ('MOT', "what's broke ?"),
#  ('mor', 'pro:int|what~aux|be&3S adj|broke ?'),
#  ('CHI', 'this is broke .'),
#  ('mor', 'pro:dem|this cop|be&3S adj|broke .'),
#  ('MOT', 'draw with another one „ okay ?'),
#  ('mor', 'v|draw prep|with qn|another pro:indef|one end|end co|okay ?'),
#  ('CHI', "that's not paper ."),
#  ('mor', 'pro:dem|that~cop|be&3S neg|not n|paper .'),
#  ('act', 'draws on the table'),
#  ('MOT', "that isn't paper ."),
#  ('mor', 'pro:dem|that cop|be&3S~neg|not n|paper .'),
#  ('CHI', "uhuh that's not paper in here ."),
#  ('mor', 'co|uhuh pro:dem|that~cop|be&3S neg|not n|paper prep|in adv|here .'),
#  ('CHI', "Momma (.) I don't want this picture ."),
#  ('mor',
#   'n:prop|Momma pro:sub|I mod|do~neg|not v|want pro:dem|this n|picture'),
#  ('MOT', 'how come ?'),
#  ('mor', 'adv:int|how v|come ?'),
#  ('CHI', 'huh .'),
#  ('mor', 'co|huh .'),
#  ('MOT', "how come you don't want that picture ?"),
#  ('mor', 'adv:int|how v|come pro:per|you mod|do~neg|not v|want pro:dem|that'),
#  ('MOT', 'you drew it .'),
#  ('mor', 'pro:per|you v|draw&PAST pro:per|it .'),
#  ('CHI', "it's broken ."),
#  ('mor', 'pro:per|it~aux|be&3S part|break&PASTP .'),
#  ('MOT', "oh ‡ the paper's ripped ."),
#  ('mor', 'co|oh beg|beg det:art|the n|paper~poss|s part|rip-PASTP .'),
#  ('MOT', 'here (.) draw on this .'),
#  ('mor', 'adv|here v|draw prep|on pro:dem|this .'),
#  ('act', 'gives Abe orange piece of paper'),
#  ('CHI', 'this is a picture .'),
#  ('mor', 'pro:dem|this cop|be&3S det:art|a n|picture .'),
#  ('CHI', 'this is not paper .'),
#  ('mor', 'pro:dem|this cop|be&3S neg|not n|paper .'),
#  ('MOT', "that's orange paper ."),
#  ('mor', 'pro:dem|that~cop|be&3S adj|orange n|paper .'),
#  ('CHI', "oh ‡ we didn't get orange paper (.) Mom ."),
#  ('mor',
#   'co|oh beg|beg pro:sub|we mod|do&PAST~neg|not v|get n|orange n|paper'),
#  ('MOT', 'go ahead .'),
#  ('mor', 'v|go adv|ahead .'),
#  ('MOT', 'you can draw on it .'),
#  ('mor', 'pro:per|you mod|can v|draw prep|on pro:per|it .'),
#  ('CHI', 'here (.) Mom see eyes .'),
#  ('mor', 'adv|here n:prop|Mom v|see n|eye-PL .'),
#  ('CHI', 'see the eyes .'),
#  ('mor', 'v|see det:art|the n|eye-PL .'),
#  ('MOT', 'oh ‡ Abe made two red eyes (.) Dad .'),
#  ('mor', 'co|oh beg|beg n:prop|Abe v|make&PAST det:num|two n|red v|eye-3S'),
#  ('CHI', 'a bigger eye this is a +...'),
#  ('mor', 'det:art|a adj|big-CP n|eye pro:dem|this cop|be&3S det:art|a +...'),
#  ('act', 'draws bigger eye'),
#  ('MOT', 'Stan (.) put this in your desk drawer .'),
#  ('mor', 'n:prop|Stan v|put&ZERO pro:dem|this prep|in det:poss|your n|desk'),
#  ('MOT', "so we'll have it when we need it next time „ okay ?"),
#  ('mor',
#   'adv|so pro:sub|we~mod|will aux|have pro:per|it conj|when pro:sub|we'),
#  ('CHI', "we haven't need it in a long time ."),
#  ('mor', 'pro:sub|we aux|have~neg|not v|need pro:per|it prep|in det:art|a'),
#  ('CHI', 'this is white .'),
#  ('mor', 'pro:dem|this cop|be&3S adj|white .'),
#  ('MOT', 'uhhuh .'),
#  ('mor', 'co|uhhuh .'),
#  ('CHI', 'this white x@l .'),
#  ('mor', 'pro:dem|this adj|white n:let|x .'),
#  ('MOT', 'you made a white x@l .'),
#  ('mor', 'pro:per|you v|make&PAST det:art|a n|white n:let|x .'),
#  ('CHI', "Mama (.) what's on here ?"),
#  ('mor', 'n:prop|Mama pro:int|what~poss|s prep|on adv|here ?'),
#  ('MOT', 'this is a brochure which tells us that our street will be repaired'),
#  ('mor',
#   'pro:dem|this cop|be&3S det:art|a n|brochure pro:rel|which v|tell-3S'),
#  ('CHI', 'Mama (.) I want white paper .'),
#  ('mor', 'n:prop|Mama pro:sub|I v|want n|white n|paper .'),
#  ('CHI', 'I want white paper now .'),
#  ('mor', 'pro:sub|I v|want n|white n|paper adv|now .'),
#  ('CHI', "that's paper , white paper ."),
#  ('mor', 'pro:dem|that~cop|be&3S n|paper cm|cm n|white n|paper .'),
#  ('MOT', 'here you go .'),
#  ('mor', 'adv|here pro:per|you v|go .'),
#  ('CHI', 'this is for you (.) Mom .'),
#  ('mor', 'pro:dem|this cop|be&3S prep|for pro:per|you n:prop|Mom .'),
#  ('MOT', 'okay ‡ I always wanted a painting .'),
#  ('mor', 'co|okay beg|beg pro:sub|I adv|always v|want-PAST det:art|a'),
#  ('CHI', 'this is be a ladder .'),
#  ('mor', 'pro:dem|this cop|be&3S cop|be det:art|a n|ladder .'),
#  ('MOT', "wow (.) Abe's making a ladder ."),
#  ('mor', 'co|wow n:prop|Abe~aux|be&3S part|make-PRESP det:art|a n|ladder .'),
#  ('CHI', 'uhhuh (.) Mommy (.) here .'),
#  ('mor', 'co|uhhuh n:prop|Mommy adv|here .'),
#  ('CHI', 'this is not for you .'),
#  ('mor', 'pro:dem|this cop|be&3S neg|not prep|for pro:per|you .'),
#  ('CHI', 'uhuh .'),
#  ('mor', 'co|uhuh .'),
#  ('CHI', 'Mommy .'),
#  ('mor', 'n:prop|Mommy .'),
#  ('CHI', 'my mommy like it .'),
#  ('mor', 'det:poss|my n|mommy prep|like pro:per|it .'),
#  ('CHI', 'my mommy liked it .'),
#  ('mor', 'det:poss|my n|mommy v|like-PAST pro:per|it .'),
#  ('CHI', 'my mommy liked it .'),
#  ('mor', 'det:poss|my n|mommy v|like-PAST pro:per|it .'),
#  ('CHI', 'you like red ?'),
#  ('mor', 'pro:per|you v|like n|red ?'),
#  ('CHI', 'here red !'),
#  ('mor', 'adv|here adj|red !'),
#  ('CHI', 'we got this and this too .'),
#  ('mor',
#   'pro:sub|we v|get&PAST pro:dem|this coord|and det:dem|this adv|too .'),
#  ('CHI', "it's ours ."),
#  ('mor', 'pro:per|it~aux|be&3S pro:poss|ours .'),
#  ('CHI', 'you like this too ?'),
#  ('mor', 'pro:per|you v|like det:dem|this adv|too ?'),
#  ('CHI', "<it's not> [//] it's orange ."),
#  ('mor', 'pro:per|it~cop|be&3S adj|orange .'),
#  ('CHI', "orange it's orange ."),
#  ('mor', 'adj|orange pro:per|it~cop|be&3S adj|orange .'),
#  ('CHI', 'this is orange dot: dot !'),
#  ('mor', 'pro:dem|this cop|be&3S adj|orange n|dot n|dot !'),
#  ('CHI', 'dot !'),
#  ('mor', 'n|dot !'),
#  ('CHI', 'dot !'),
#  ('mor', 'n|dot !'),
#  ('CHI', 'uhhuh Momma (.) come see this ladder (.) I made .'),
#  ('mor', 'co|uhhuh n:prop|Momma v|come v|see pro:dem|this n|ladder pro:sub|I'),
#  ('MOT', "that's really a neat ladder ."),
#  ('mor',
#   'pro:dem|that~cop|be&3S adv|real&dadj-LY det:art|a adj|neat n|ladder'),
#  ('CHI', "it's for firemans [: firemen] [* s] ."),
#  ('mor', 'pro:per|it~aux|be&3S prep|for n|+n|fire+n|man&PL .'),
#  ('MOT', "it's for fireman to climb up ?"),
#  ('mor',
#   'pro:per|it~aux|be&3S prep|for n|+n|fire+n|man inf|to v|climb adv|up'),
#  ('CHI', 'uhhuh fireman put out fire !'),
#  ('mor', 'co|uhhuh n|+n|fire+n|man v|put&ZERO adv|out n|fire !'),
#  ('MOT', 'uhhuh and painters use ladders to paint buildings .'),
#  ('mor', 'co|uhhuh coord|and n|paint&dv-AGT-PL n|use n|ladder-PL prep|to'),
#  ('CHI', 'not this house !'),
#  ('mor', 'neg|not pro:dem|this n|house !'),
#  ('MOT', 'not yet but they will soon .'),
#  ('mor', 'neg|not adv|yet conj|but pro:sub|they mod|will adv|soon .'),
#  ('CHI', 'this is ours .'),
#  ('mor', 'pro:dem|this cop|be&3S pro:poss|ours .'),
#  ('CHI', 'this is ours .'),
#  ('mor', 'pro:dem|this cop|be&3S pro:poss|ours .'),
#  ('CHI', 'what happen (.) Mom ?'),
#  ('mor', 'pro:int|what v|happen n:prop|Mom ?'),
#  ('MOT', 'to what ?'),
#  ('mor', 'prep|to pro:int|what ?'),
#  ('CHI', 'to this house .'),
#  ('mor', 'prep|to pro:dem|this n|house .'),
#  ('MOT', 'the sun went behind a cloud .'),
#  ('mor', 'det:art|the n|sun v|go&PAST prep|behind det:art|a n|cloud .'),
#  ('MOT', "so it's not as bright in here ."),
#  ('mor', 'adv|so pro:per|it~cop|be&3S neg|not prep|as adj|bright prep|in'),
#  ('CHI', 'I wanna turn it on .'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|turn pro:per|it adv|on .'),
#  ('MOT', 'turn what on ?'),
#  ('mor', 'v|turn pro:int|what adv|on ?'),
#  ('CHI', 'my light on .'),
#  ('mor', 'det:poss|my n|light adv|on .'),
#  ('CHI', "you're not Abe !"),
#  ('mor', 'pro:per|you~aux|be&PRES neg|not n:prop|Abe !'),
#  ('MOT', "that's right ."),
#  ('mor', 'pro:dem|that~cop|be&3S n|right .'),
#  ('CHI', "you're not Stan ."),
#  ('mor', 'pro:per|you~aux|be&PRES neg|not n:prop|Stan .'),
#  ('CHI', 'you are Ann !'),
#  ('mor', 'pro:per|you cop|be&PRES n:prop|Ann !'),
#  ('MOT', "that's right ."),
#  ('mor', 'pro:dem|that~cop|be&3S n|right .'),
#  ('MOT', "I'm Ann ."),
#  ('mor', 'pro:sub|I~aux|be&1S n:prop|Ann .'),
#  ('CHI', 'and two eyes (.) Mom .'),
#  ('mor', 'coord|and det:num|two n|eye-PL n:prop|Mom .'),
#  ('MOT', "uhhuh I'm going to go out and water the garden ."),
#  ('mor', 'co|uhhuh pro:sub|I~aux|be&1S part|go-PRESP inf|to v|go adv|out'),
#  ('CHI', "I don't want to ."),
#  ('mor', 'pro:sub|I mod|do~neg|not v|want prep|to .'),
#  ('MOT', 'okay ‡ you can stay in here with Daddy .'),
#  ('mor', 'co|okay beg|beg pro:per|you mod|can n|stay prep|in adv|here'),
#  ('CHI', 'where my ladder ?'),
#  ('mor', 'adv:int|where det:poss|my n|ladder ?'),
#  ('CHI', 'here it is .'),
#  ('mor', 'adv|here pro:per|it cop|be&3S .'),
#  ('CHI', 'wanna poopoo Daddy .'),
#  ('mor', 'mod:aux|wanna v|+on|poo+on|poo n:prop|Daddy .'),
#  ('CHI', 'I wanna poopoo .'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|+on|poo+on|poo .'),
#  ('CHI', 'I wanna come back hurry !'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|come adj|back n|hurry !'),
#  ('CHI', 'Daddy this is for you .'),
#  ('mor', 'n:prop|Daddy pro:dem|this cop|be&3S prep|for pro:per|you .'),
#  ('CHI', 'you take for school !'),
#  ('mor', 'pro:per|you v|take prep|for n|school !'),
#  ('CHI', 'I wanna go for school with you .'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|go prep|for n|school prep|with'),
#  ('CHI', 'okay ‡ I wanna watch tv .'),
#  ('mor', 'co|okay beg|beg pro:sub|I mod:aux|wanna v|watch n|tv .'),
#  ('CHI', 'I wanna watch tv .'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|watch n|tv .'),
#  ('CHI', "why don't we play a game „ okay ?"),
#  ('mor', 'adv:int|why mod|do~neg|not pro:sub|we v|play det:art|a n|game'),
#  ('CHI', 'Daddy (.) birdie !'),
#  ('mor', 'n:prop|Daddy n|bird-DIM !'),
#  ('act', 'looking out window'),
#  ('CHI', 'outside .'),
#  ('mor', 'adv|outside .'),
#  ('CHI', 'uhhuh (.) my mommy got a doggy .'),
#  ('mor', 'co|uhhuh det:poss|my n|mommy v|get&PAST det:art|a n|dog-DIM .'),
#  ('CHI', 'uhhuh in here .'),
#  ('mor', 'co|uhhuh adv|in adv|here .'),
#  ('CHI', 'and we go to park .'),
#  ('mor', 'coord|and pro:sub|we v|go inf|to v|park .'),
#  ('CHI', 'we go park afternoon .'),
#  ('mor', 'pro:sub|we v|go n|park n|afternoon .'),
#  ('CHI', 'uhhuh Como_Park .'),
#  ('mor', 'co|uhhuh n:prop|Como_Park .'),
#  ('CHI', 'to Como_Park: .'),
#  ('mor', 'prep|to n:prop|Como_Park .'),
#  ('CHI', 'I wanna go to Como_Park .'),
#  ('mor', 'pro:sub|I mod:aux|wanna v|go prep|to n:prop|Como_Park .'),
#  ('CHI', 'see the ducks ?'),
#  ('mor', 'v|see det:art|the n|duck-PL ?'),
#  ('CHI', 'uhhuh I like that .'),
#  ('mor', 'co|uhhuh pro:sub|I co|like pro:dem|that .'),
#  ('CHI', "I'm not likable !"),
#  ('mor', 'pro:sub|I~cop|be&1S neg|not adj|like&dv-ABLE !'),
#  ('CHI', 'you are likable .'),
#  ('mor', 'pro:per|you cop|be&PRES adj|like&dv-ABLE .'),
#  ('CHI', 'uhhuh .'),
#  ('mor', 'co|uhhuh .'),
#  ('CHI', 'a cow in the barn .'),
#  ('mor', 'det:art|a n|cow prep|in det:art|the n|barn .'),
#  ('CHI', 'uhhuh that barn .'),
#  ('mor', 'co|uhhuh pro:rel|that n|barn .'),
#  ('CHI', "uhhuh (.) oh (.) I'm sorry ."),
#  ('mor', 'co|uhhuh co|oh pro:sub|I~cop|be&1S adj|sorry .'),
#  ('act', 'fell on Father'),
#  ('CHI', 'girl (.) girl (.) girl !'),
#  ('mor', 'n|girl n|girl n|girl !'),
#  ('CHI', "who's in the car ?"),
#  ('mor', 'pro:int|who~cop|be&3S prep|in det:art|the n|car ?'),
#  ('CHI', "a man's in the car ."),
#  ('mor', 'det:art|a n|man~poss|s prep|in det:art|the n|car .'),
#  ('CHI', 'a funny man in the car and a silly man in the car .'),
#  ('mor', 'det:art|a adj|fun&dn-Y n|man prep|in det:art|the n|car coord|and'),
#  ('CHI', "I didn't got you ."),
#  ('mor', 'pro:sub|I mod|do&PAST~neg|not v|get&PAST pro:per|you .'),
#  ('act', '<bef> trying to hit me'),
#  ('CHI', "no ‡ I didn't ."),
#  ('mor', 'co|no beg|beg pro:sub|I mod|do&PAST~neg|not .'),
#  ('CHI', 'I got you .'),
#  ('mor', 'pro:sub|I v|get&PAST pro:per|you .'),
#  ('CHI', 'I got you .'),
#  ('mor', 'pro:sub|I v|get&PAST pro:per|you .'),
#  ('CHI', 'help me !'),
#  ('mor', 'v|help pro:obj|me !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'no !'),
#  ('mor', 'co|no !'),
#  ('CHI', 'I got it .'),
#  ('mor', 'pro:sub|I v|get&PAST pro:per|it .'),
#  ('CHI', 'I got it .'),
#  ('mor', 'pro:sub|I v|get&PAST pro:per|it .'),
#  ('CHI', "you can't get it ."),
#  ('mor', 'pro:per|you mod|can~neg|not v|get pro:per|it .'),
#  ('CHI', "you can't get it ."),
#  ('mor', 'pro:per|you mod|can~neg|not v|get pro:per|it .'),
#  ('CHI', "you can't ."),
#  ('mor', 'pro:per|you mod|can~neg|not .'),
#  ('CHI', 'I can .'),
#  ('mor', 'pro:sub|I mod|can .'),
#  ('CHI', 'upside down merrygoround merrygoround .'),
#  ('mor', 'adv|upside prep|down n|+adj|merry+v|go+adj|round'),
#  ('act', 'goes around in circles'),
#  ('CHI', 'Poe_Ray_Me read that at the store „ right ?'),
#  ('mor', 'n:prop|Poe_Ray_Me v|read&ZERO pro:dem|that prep|at det:art|the'),
#  ('CHI', 'uhhuh .'),
#  ('mor', 'co|uhhuh .'),
#  ('CHI', "I didn't got a sore ."),
#  ('mor', 'pro:sub|I mod|do&PAST~neg|not v|get&PAST det:art|a n|sore .'),
#  ('CHI', 'uhuh .'),
#  ('mor', 'co|uhuh .'),
#  ('CHI', 'see this ?'),
#  ('mor', 'v|see pro:dem|this ?'),
#  ('CHI', 'I hurt self outside .'),
#  ('mor', 'pro:sub|I v|hurt&ZERO n|self adv|outside .'),
#  ('CHI', 'on a chair , a green chair .'),
#  ('mor', 'prep|on det:art|a n|chair cm|cm det:art|a n|green n|chair .'),
#  ('CHI', 'stuck .'),
#  ('mor', 'v|stick&PAST .'),
#  ('CHI', 'what fingernails ?'),
#  ('mor', 'pro:int|what n|+n|finger+n|nail-PL ?'),
#  ('CHI', "uhhuh I don't want a fingernail cut ."),
#  ('mor', 'co|uhhuh pro:sub|I mod|do~neg|not v|want det:art|a'),
#  ('CHI', "I don't want a fingernail cut ."),
#  ('mor', 'pro:sub|I mod|do~neg|not v|want det:art|a n|+n|finger+n|nail'),
#  ('CHI', "I don't want to you do on your toes !"),
#  ('mor', 'pro:sub|I mod|do~neg|not v|want prep|to pro:per|you v|do prep|on'),
#  ('CHI', 'no ‡ my toes are not pretty good shape .'),
#  ('mor', 'co|no beg|beg det:poss|my n|toe-PL cop|be&PRES neg|not adv|pretty'),
#  ('CHI', 'they are round and circles .'),
#  ('mor', 'pro:sub|they cop|be&PRES adv|round coord|and n|circle-PL .'),
#  ('CHI', 'you funny dummy .'),
#  ('mor', 'pro:per|you adj|fun&dn-Y adj|dummy .'),
#  ('CHI', 'you are a silly goose too .'),
#  ('mor', 'pro:per|you cop|be&PRES det:art|a adj|silly n|goose adv|too .'),
#  ('CHI', 'a goose flewed [: flew] [* m:ed] .'),
#  ('mor', 'det:art|a n|goose v|fly&PAST .'),
#  ('CHI', 'no ‡ flew away .'),
#  ('mor', 'co|no beg|beg v|fly&PAST adv|away .'),
#  ('CHI', 'you flew away .'),
#  ('mor', 'pro:per|you v|fly&PAST adv|away .'),
#  ('CHI', 'no ‡ you .'),
#  ('mor', 'co|no beg|beg pro:per|you .')]
